# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_excel('Amazon_Diwali_Product_Sales.xlsx')

# %%
print(df.head())
# Out:
#     Order_ID       Date Customer_ID Product_Category  Product_Name  Quantity  \
# 0  ORD100002 2025-02-27    CUST5808      Electronics        Tablet         3
# 1  ORD100003 2025-02-24    CUST5889      Electronics    Headphones         5
# 2  ORD100004 2025-06-15    CUST9005         Clothing         Saree         5
# 3  ORD100005 2025-02-10    CUST2403   Home & Kitchen  Cookware Set         1
# 4  ORD100006 2025-05-16    CUST9645         Clothing         Jeans         4
#
#    Unit_Price_INR  Total_Sales_INR    Payment_Method Delivery_Status  \
# 0        38476.22        115428.66  Cash on Delivery       Delivered
# 1        38145.72        190728.60       Credit Card       Delivered
# 2        45940.98        229704.90               UPI       Delivered
# 3        12195.41         12195.41  Cash on Delivery       Delivered
# 4        47353.06        189412.24  Cash on Delivery       Delivered
#
#    Review_Rating (out of 5)         Review_Text              State Country
# ...

# %%
(df == 0 ) .sum()
# Out:
# Order_ID                    0
# Date                        0
# Customer_ID                 0
# Product_Category            0
# Product_Name                0
# Quantity                    0
# Unit_Price_INR              0
# Total_Sales_INR             0
# Payment_Method              0
# Delivery_Status             0
# Review_Rating (out of 5)    0
# Review_Text                 0
# State                       0
# Country                     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Order_ID                    0
# Date                        0
# Customer_ID                 0
# Product_Category            0
# Product_Name                0
# Quantity                    0
# Unit_Price_INR              0
# Total_Sales_INR             0
# Payment_Method              0
# Delivery_Status             0
# Review_Rating (out of 5)    0
# Review_Text                 0
# State                       0
# Country                     0
# dtype: int64

# %%
print(df.tail())
# Out:
#        Order_ID       Date Customer_ID Product_Category      Product_Name  \
# 4246  ORD114992 2025-07-06    CUST8894           Beauty        Face Cream
# 4247  ORD114993 2025-04-01    CUST6180            Books            Comics
# 4248  ORD114995 2025-04-12    CUST2822           Beauty          Lipstick
# 4249  ORD114996 2025-08-29    CUST6143           Beauty           Shampoo
# 4250  ORD114997 2025-01-27    CUST6747            Books  Science Textbook
#
#       Quantity  Unit_Price_INR  Total_Sales_INR Payment_Method  \
# 4246         4        48974.78        195899.12            UPI
# 4247         5        32721.01        163605.05    Credit Card
# 4248         4        36421.54        145686.16            UPI
# 4249         4        18158.02         72632.08     Debit Card
# 4250         1        38864.05         38864.05            UPI
#
#      Delivery_Status  Review_Rating (out of 5)                 Review_Text  \
# ...

# %% [markdown]
# # Create the heatmap

# %%
numeric_df = df.select_dtypes(include = ['int64' ,'float64'])

# %%
corr_matrix = numeric_df.corr()

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    linewidths=0.5
)

plt.title("Correlation Heatmap")
plt.show()

# %%
category_sales = df.groupby('Product_Category')['Total_Sales_INR'].sum()

plt.figure(figsize=(7,5))

category_sales.plot(kind='bar')

plt.title("Total Sales by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Sales")

plt.show()

# %%
df.head()
# Out:
#     Order_ID       Date Customer_ID Product_Category  Product_Name  Quantity  \
# 0  ORD100002 2025-02-27    CUST5808      Electronics        Tablet         3
# 1  ORD100003 2025-02-24    CUST5889      Electronics    Headphones         5
# 2  ORD100004 2025-06-15    CUST9005         Clothing         Saree         5
# 3  ORD100005 2025-02-10    CUST2403   Home & Kitchen  Cookware Set         1
# 4  ORD100006 2025-05-16    CUST9645         Clothing         Jeans         4
#
#    Unit_Price_INR  Total_Sales_INR    Payment_Method Delivery_Status  \
# 0        38476.22        115428.66  Cash on Delivery       Delivered
# 1        38145.72        190728.60       Credit Card       Delivered
# 2        45940.98        229704.90               UPI       Delivered
# 3        12195.41         12195.41  Cash on Delivery       Delivered
# 4        47353.06        189412.24  Cash on Delivery       Delivered
#
#    Review_Rating (out of 5)         Review_Text              State Country
# ...

# %%
category_sales = df.groupby('Product_Category') ['Total_Sales_INR'].sum()

# 3. Add labels and a title
plt.xlabel('Product_Category')
plt.ylabel('Total_Sales_INR')
plt.title('Sales By There Product Category ')
category_sales.plot(kind = 'bar')
plt.figure(figsize = (7,5))
plt.show()

# %%
plt.figure (figsize = (8,5))
sns.countplot(x = 'Payment_Method' , data = df ) 
plt.title('Payment Method Usage')
plt.show()

# %% [markdown]
# # Bar Chart

# %%
state_sales = df.groupby('State') ['Total_Sales_INR'] .sum()
plt.figure(figsize = (12 , 5)) 
state_sales .plot ( kind = 'bar')
plt.title('Total sales by State ' ) 
plt.xlable('State')
plt.ylable('Total Sales')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 5
#       3 state_sales .plot ( kind = 'bar')
#       4 plt.title('Total sales by State ' )
# ----> 5 plt.xlable('State')
#       6 plt.ylable('Total Sales')
#       7 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'
